# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn.metrics import mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA


import warnings
warnings.filterwarnings('ignore')

# %%
mpl.rcParams['figure.figsize'] = (12, 8)
mpl.rcParams['axes.grid'] = False

# %%
df = pd.read_csv("Anon_Cust_Order_Data.csv")
df.head()
# Out:
#    Order_ID  CustomerID           Date State         City    ZIP  \
# 0    176558           1   4/19/19 8:46    TX       Dallas  75001
# 1    176559           2   4/7/19 22:30    MA       Boston   2215
# 2    176560           3  4/12/19 14:38    CA  Los Angeles  90001
# 3    176560           3  4/12/19 14:38    CA  Los Angeles  90001
# 4    176561           4   4/30/19 9:27    CA  Los Angeles  90001
#
#                       Product  Quantity  Price_Each
# 0        USB-C Charging Cable         2       11.95
# 1  Bose SoundSport Headphones         1       99.99
# 2                Google Phone         1      600.00
# 3            Wired Headphones         1       11.99
# 4            Wired Headphones         1       11.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185950 entries, 0 to 185949
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Order_ID    185950 non-null  int64
#  1   CustomerID  185950 non-null  int64
#  2   Date        185950 non-null  object
#  3   State       185950 non-null  object
#  4   City        185950 non-null  object
#  5   ZIP         185950 non-null  int64
#  6   Product     185950 non-null  object
#  7   Quantity    185950 non-null  int64
#  8   Price_Each  185950 non-null  float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 12.8+ MB

# %% [markdown]
# ## Exploratory Data Analysis
#
# First, we see that the date is stored as an object. Will update to datetime format.
#
# Let's get to know the dataset
# - Regional
# - Products
# - Price Range
#
# - Bring in basic MSA information
#
# Observations:
# - Group by CustomerID to get statistics on cart size
# - Figure out product characteristics and a tagging rationale
#
# Helpful resource: https://otexts.com/fpp2/hierarchical.html
#
# Census Regional Classification: https://www2.census.gov/geo/pdfs/maps-data/maps/reference/us_regdiv.pdf

# %%
region = {'CT': 'Northeast', 'ME':'Northeast', 'MA':'Northeast', 'NH':'Northeast', 'RI': 'Northeast', 'VT':'Northeast',
         'NJ':'Northeast', 'NY':'Northeast', 'PA':'Northeast', 'IN': 'Midwest', 'IL': 'Midwest', 'MI': 'Midwest', 'OH': 'Midwest',
         'WI': 'Midwest', 'IA': 'Midwest', 'KS': 'Midwest', 'MN': 'Midwest', 'MO': 'Midwest', 'NE': 'Midwest', 'ND': 'Midwest',
         'SD': 'Midwest', 'DE': 'South', 'DC': 'South', 'FL': 'South', 'GA': 'South', 'MD': 'South', 'NC': 'South', 'SC': 'South',
         'VA': 'South', 'WV': 'South', 'AL': 'South', 'KY': 'South', 'MS': 'South', 'TN': 'South', 'AK': 'South', 'LA': 'South',
         'OK': 'South', 'TX': 'South', 'AZ': 'West', 'CO': 'West', 'ID': 'West', 'NM': 'West', 'MT': 'West',
         'UT': 'West', 'NV': 'West', 'WY': 'West', 'AK': 'West', 'CA': 'West', 'HI': 'West', 'OR': 'West', 'WA': 'West',}


division = {'CT': 'New_Eng', 'ME':'New_Eng', 'MA':'New_Eng', 'NH':'New_Eng', 'RI': 'New_Eng', 'VT':'New_Eng',
         'NJ':'Middle_Atl', 'NY':'Middle_Atl', 'PA':'Middle_Atl', 'IN': 'East_No_Cent', 'IL': 'East_No_Cent', 'MI': 'East_No_Cent', 'OH': 'East_No_Cent',
         'WI': 'East_No_Cent', 'IA': 'We_No_Cent', 'KS': 'We_No_Cent', 'MN': 'We_No_Cent', 'MO': 'We_No_Cent', 'NE': 'We_No_Cent', 'ND': 'We_No_Cent',
         'SD': 'We_No_Cent', 'DE': 'So_Atl', 'DC': 'So_Atl', 'FL': 'So_Atl', 'GA': 'So_Atl', 'MD': 'So_Atl', 'NC': 'So_Atl', 'SC': 'So_Atl',
         'VA': 'So_Atl', 'WV': 'So_Atl', 'AL': 'East_So_Cent', 'KY': 'East_So_Cent', 'MS': 'East_So_Cent', 'TN': 'East_So_Cent', 'AK': 'We_So_Cent', 'LA': 'We_So_Cent',
         'OK': 'We_So_Cent', 'TX': 'We_So_Cent', 'AZ': 'Mountain', 'CO': 'Mountain', 'ID': 'Mountain', 'NM': 'Mountain', 'MT': 'Mountain',
         'UT': 'Mountain', 'NV': 'Mountain', 'WY': 'Mountain', 'AK': 'Pacific', 'CA': 'Pacific', 'HI': 'Pacific', 'OR': 'Pacific', 'WA': 'Pacific',}

# %%
df['Date'] =  pd.to_datetime(df['Date'], utc=True).dt.date
df['Date'] =  pd.to_datetime(df['Date'], infer_datetime_format=True)
df['Region'] = df['State'].map(region)
df['Division'] = df['State'].map(division)

# %%
df = df.sort_values('Date').reset_index(drop=True)

## Drop data from 2020-01-01 as it's skewing results:
df = df.loc[0:185915] 

display(df.tail(20))
# Out:
#         Order_ID  CustomerID       Date State           City    ZIP  \
# 185896    310437       41165 2019-12-31    CA    Los Angeles  90001
# 185897    307873       38904 2019-12-31    CA  San Francisco  94016
# 185898    306319       37512 2019-12-31    NY  New York City  10001
# 185899    298051       30051 2019-12-31    CA  San Francisco  94016
# 185900    306279       26700 2019-12-31    CA    Los Angeles  90001
# 185901    314935       45106 2019-12-31    CA    Los Angeles  90001
# 185902    313883       44208 2019-12-31    GA        Atlanta  30301
# 185903    318900       33695 2019-12-31    TX         Dallas  75001
# 185904    314981       45147 2019-12-31    TX         Dallas  75001
# 185905    298109       30106 2019-12-31    GA        Atlanta  30301
# 185906    313185       43593 2019-12-31    CA  San Francisco  94016
# 185907    307159        7775 2019-12-31    GA        Atlanta  30301
# 185908    295774        8559 2019-12-31    CA    Los Angeles  90001
# 185909    301118       32836 2019-12-31    TX         Dallas  75001
# 185910    308365       39341 2019-12-31    CA  San Francisco  94016
# 185911    301384       33078 2019-12-31    GA        Atlanta  30301
# 185912    313859       44187 2019-12-31    WA        Seattle  98101
# 185913    298078       30077 2019-12-31    TX         Dallas  75001
# 185914    301150       32865 2019-12-31    GA        Atlanta  30301
# 185915    313858       44186 2019-12-31    CA  San Francisco  94016
#
#                            Product  Quantity  Price_Each     Region  \
# 185896        USB-C Charging Cable         1       11.95       West
# 185897      AAA Batteries (4-pack)         1        2.99       West
# 185898        USB-C Charging Cable         1       11.95  Northeast
# 185899            Wired Headphones         1       11.99       West
# 185900    Lightning Charging Cable         1       14.95       West
# 185901            Wired Headphones         1       11.99       West
# 185902       AA Batteries (4-pack)         1        3.84      South
# 185903            Wired Headphones         1       11.99      South
# 185904            27in FHD Monitor         1      149.99      South
# 185905               Flatscreen TV         1      300.00      South
# 185906                20in Monitor         1      109.99       West
# 185907    Lightning Charging Cable         1       14.95      South
# 185908  Bose SoundSport Headphones         1       99.99       West
# 185909            Wired Headphones         1       11.99      South
# 185910        USB-C Charging Cable         1       11.95       West
# 185911      AAA Batteries (4-pack)         2        2.99      South
# 185912       AA Batteries (4-pack)         1        3.84       West
# 185913       AA Batteries (4-pack)         2        3.84      South
# 185914        USB-C Charging Cable         1       11.95      South
# 185915      AAA Batteries (4-pack)         1        2.99       West
#
#           Division
# 185896     Pacific
# 185897     Pacific
# 185898  Middle_Atl
# 185899     Pacific
# 185900     Pacific
# 185901     Pacific
# 185902      So_Atl
# 185903  We_So_Cent
# 185904  We_So_Cent
# 185905      So_Atl
# 185906     Pacific
# 185907      So_Atl
# 185908     Pacific
# 185909  We_So_Cent
# 185910     Pacific
# 185911      So_Atl
# 185912     Pacific
# 185913  We_So_Cent
# 185914      So_Atl
# 185915     Pacific

# %% [markdown]
# If there are columns that we won't need for analysis, we can drop them.
#
# First, let's understand if order number and customer number are duplicative:

# %%
print(len(df['Order_ID'].unique()), len(df['CustomerID'].unique()))

display (df[['Order_ID', 'CustomerID']].sort_values('CustomerID').head(10))
# Out:
# 178406 140768
#         Order_ID  CustomerID
# 47882     176558           1
# 40715     176559           2
# 43843     176560           3
# 43846     176560           3
# 54821     176561           4
# 4384      150323           5
# 53949     176562           5
# 4528      150323           5
# 4499      150323           5
# 157976    292199           5

# %% [markdown]
# Confirmed that Order_ID and CustomerID contain different information. However, for our baseline timeseries forecast, we won't be aggregating that infomation so can drop those columns for now:

# %%
to_drop = ['Order_ID', 'CustomerID']

for col in df.columns:
    if col in to_drop:
        df.drop(col, axis=1, inplace=True)
        
display(df.head())
# Out:
#         Date State           City    ZIP                 Product  Quantity  \
# 0 2019-01-01    WA        Seattle  98101  27in 4K Gaming Monitor         1
# 1 2019-01-01    TX         Dallas  75001      Macbook Pro Laptop         1
# 2 2019-01-01    CA    Los Angeles  90001         ThinkPad Laptop         1
# 3 2019-01-01    TX         Austin  73301           Flatscreen TV         1
# 4 2019-01-01    NY  New York City  10001           Flatscreen TV         1
#
#    Price_Each     Region    Division
# 0      389.99       West     Pacific
# 1     1700.00      South  We_So_Cent
# 2      999.99       West     Pacific
# 3      300.00      South  We_So_Cent
# 4      300.00  Northeast  Middle_Atl

# %% [markdown]
# ### Explore Geographic Subgroups

# %%
division_sum = df[['Region', 'Division', 'Quantity']].groupby(by=['Region', 'Division']).sum().reset_index()
state_sum = df[['State', 'Quantity']].groupby(by=['State']).sum().reset_index()
display(division_sum)
display(state_sum)
# Out:
#       Region    Division  Quantity
# 0  Northeast  Middle_Atl     27916
# 1  Northeast     New_Eng     25274
# 2      South      So_Atl     16602
# 3      South  We_So_Cent     27879
# 4       West     Pacific    111367
#   State  Quantity
# 0    CA     83514
# 1    GA     16602
# 2    MA     22524
# 3    ME      2750
# 4    NY     27916
# 5    OR     11301
# 6    TX     27879
# 7    WA     16552

# %%
fig, axes = plt.subplots(2, 1, figsize=(12,6), dpi= 80)
sns.barplot(x='Division', y='Quantity', data=division_sum, ax=axes[0])
sns.barplot(x='State', y='Quantity', data=state_sum, ax=axes[1])
# Out:
# <AxesSubplot: xlabel='State', ylabel='Quantity'>

# %% [markdown]
# ### Explore Products

# %%
print("Number of customer records:", len(df))
# Out:
# Number of customer records: 185916

# %%
total_prod = df[['Product', 'Quantity']].groupby(by=['Product']).count().reset_index()
prod_by_region = df[['Product', 'Region', 'Quantity']].groupby(by=['Product', 'Region']).sum()

sns.barplot(x='Product', y='Quantity', data=total_prod)
plt.xticks(rotation=270)
plt.tight_layout()
plt.show()

#sns.barplot(x='Region', y='Quantity', data=prod_by_region, ax=axes[1])

# %%
display(prod_by_region)
# Out:
#                                       Quantity
# Product                    Region
# 20in Monitor               Northeast      1013
#                            South           914
#                            West           2199
# 27in 4K Gaming Monitor     Northeast      1602
#                            South          1291
#                            West           3350
# 27in FHD Monitor           Northeast      1983
#                            South          1535
#                            West           4029
# 34in Ultrawide Monitor     Northeast      1615
#                            South          1322
#                            West           3262
# AA Batteries (4-pack)      Northeast      7035
#                            South          5878
#                            West          14722
# AAA Batteries (4-pack)     Northeast      7940
#                            South          6531
#                            West          16541
# Apple Airpods Headphones   Northeast      3984
#                            South          3347
#                            West           8326
# Bose SoundSport Headphones Northeast      3389
#                            South          2854
#                            West           7211
# Flatscreen TV              Northeast      1243
#                            South          1069
#                            West           2506
# Google Phone               Northeast      1428
#                            South          1186
#                            West           2917
# LG Dryer                   Northeast       142
#                            South           158
#                            West            346
# LG Washing Machine         Northeast       168
#                            South           129
#                            West            369
# Lightning Charging Cable   Northeast      5796
#                            South          5049
#                            West          12366
# Macbook Pro Laptop         Northeast      1199
#                            South          1011
#                            West           2517
# ThinkPad Laptop            Northeast      1059
#                            South           912
#                            West           2157
# USB-C Charging Cable       Northeast      6167
#                            South          5018
#                            West          12786
# Vareebadd Phone            Northeast       511
#                            South           459
#                            West           1097
# Wired Headphones           Northeast      5204
#                            South          4378
#                            West          10971
# iPhone                     Northeast      1712
#                            South          1440
#                            West           3695

# %% [markdown]
# Geographically, we have 3 regions, 5 divisions, and 8 states in our dataset.

# %% [markdown]
# ### Look at total product quantity over time

# %%
total_quant = df[['Date', 'Quantity']].groupby('Date').sum()

sns.lineplot(data=total_quant, x='Date', y='Quantity')
# Out:
# <AxesSubplot: xlabel='Date', ylabel='Quantity'>

# %%
## Aggregate my month:
grouped_by_month = total_quant.resample('MS').mean()
sns.lineplot(x='Date', y='Quantity', data=grouped_by_month)

## Aggregate my week:
grouped_by_week = total_quant.resample('W').mean()
sns.lineplot(x='Date', y='Quantity', data=grouped_by_week)
# Out:
# <AxesSubplot: xlabel='Date', ylabel='Quantity'>

# %%
df_date = df[['Date', 'Product', 'Quantity']].sort_values(by='Date').set_index('Date')
df_date = df_date.groupby(by=['Date','Product']).sum().reset_index()
display(df_date)
# Out:
#            Date                 Product  Quantity
# 0    2019-01-01            20in Monitor         4
# 1    2019-01-01  27in 4K Gaming Monitor         7
# 2    2019-01-01        27in FHD Monitor         8
# 3    2019-01-01  34in Ultrawide Monitor        18
# 4    2019-01-01   AA Batteries (4-pack)        33
# ...         ...                     ...       ...
# 6807 2019-12-31         ThinkPad Laptop        26
# 6808 2019-12-31    USB-C Charging Cable       103
# 6809 2019-12-31         Vareebadd Phone        10
# 6810 2019-12-31        Wired Headphones        90
# 6811 2019-12-31                  iPhone        23
#
# [6812 rows x 3 columns]

# %%
products_wide = df_date.pivot(index='Date', columns='Product', values='Quantity')
display(products_wide.head())
# Out:
# Product     20in Monitor  27in 4K Gaming Monitor  27in FHD Monitor  \
# Date
# 2019-01-01           4.0                     7.0               8.0
# 2019-01-02           9.0                    14.0              17.0
# 2019-01-03           6.0                    14.0              16.0
# 2019-01-04           7.0                     8.0              15.0
# 2019-01-05           5.0                    13.0              16.0
#
# Product     34in Ultrawide Monitor  AA Batteries (4-pack)  \
# Date
# 2019-01-01                    18.0                   33.0
# 2019-01-02                     8.0                   54.0
# 2019-01-03                    12.0                   44.0
# 2019-01-04                    11.0                   30.0
# 2019-01-05                     8.0                   50.0
#
# Product     AAA Batteries (4-pack)  Apple Airpods Headphones  \
# Date
# 2019-01-01                    61.0                      21.0
# 2019-01-02                    43.0                      35.0
# 2019-01-03                    40.0                      21.0
# 2019-01-04                    41.0                      24.0
# 2019-01-05                    63.0                      23.0
#
# Product     Bose SoundSport Headphones  Flatscreen TV  Google Phone  LG Dryer  \
# Date
# 2019-01-01                        15.0            9.0          12.0       1.0
# 2019-01-02                        19.0            9.0          12.0       3.0
# 2019-01-03                        24.0            5.0           8.0       1.0
# 2019-01-04                        16.0           10.0          11.0       3.0
# 2019-01-05                        23.0            5.0          11.0       NaN
#
# Product     LG Washing Machine  Lightning Charging Cable  Macbook Pro Laptop  \
# Date
# 2019-01-01                 2.0                      42.0                 9.0
# 2019-01-02                 1.0                      36.0                 9.0
# 2019-01-03                 3.0                      43.0                 4.0
# 2019-01-04                 1.0                      36.0                10.0
# 2019-01-05                 1.0                      41.0                 4.0
#
# Product     ThinkPad Laptop  USB-C Charging Cable  Vareebadd Phone  \
# Date
# 2019-01-01              9.0                  43.0              2.0
# 2019-01-02             11.0                  36.0              2.0
# 2019-01-03              3.0                  43.0              1.0
# 2019-01-04              8.0                  57.0              7.0
# 2019-01-05              7.0                  30.0              1.0
#
# Product     Wired Headphones  iPhone
# Date
# 2019-01-01              31.0    16.0
# 2019-01-02              35.0    15.0
# 2019-01-03              31.0    11.0
# 2019-01-04              28.0     7.0
# 2019-01-05              47.0     7.0

# %%
sns.lineplot(data=products_wide)
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# ## Products by Category

# %%
# Create some basic product mapping:
all_prods = df['Product'].unique()
all_prods

cats = ['monitors', 'computers', 'phones', 'appliances', 'accessories']

monitors = []
computers = []
phones = []
appliances = []
accessories = []

for prod in all_prods:
    if 'Monitor' in prod:
        monitors.append(prod)
    elif 'Laptop' in prod:
        computers.append(prod)
    elif 'Phone' in prod:
        phones.append(prod)
    elif 'Washing' in prod or 'Dryer' in prod or 'TV' in prod:
        appliances.append(prod)
    else:
        accessories.append(prod)

assert len(monitors) + len(computers) + len(phones) + len(appliances) + len(accessories) == len(all_prods)

# %%
def prod_cat_freq(df, prod_cat, freq='W'):
    new_df = df[df["Product"].isin(prod_cat)].set_index('Date')
    new_df = new_df['Quantity'].resample(freq).sum()
    # Drop the last row:
    new_df.drop(new_df.tail(1).index,inplace=True)
    return new_df

# %%
df_monitors = prod_cat_freq(df, monitors)
df_computers = prod_cat_freq(df, computers)
df_phones = prod_cat_freq(df, phones)
df_appliances = prod_cat_freq(df, appliances)
df_accessories = prod_cat_freq(df, accessories)

dfs = [df_monitors, df_computers, df_phones, df_appliances, df_accessories]

# %% [markdown]
# ### Breakout product sales by defined category

# %%
#from matplotlib.colors import ListedColormap, LinearSegmentedColormap
#colors = mpl.colormaps['viridis'].resampled(len(dfs))
#colors = colors(np.linspace(0, 1, len(dfs)))

# %%
## Plot the Weekly Quantities by Product Category:
fig, ax = plt.subplots(figsize=(10, 8))

for i in range(len(dfs)):
    #ax.plot(dfs[i], color=colors[i], label = cats[i])
    ax.plot(dfs[i], label = cats[i])
    
plt.xlabel("Date")
plt.ylabel("Quantity")
plt.title('Product Sales by Category')
plt.legend()
plt.show()
